# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
apple_length = np.random.random(100) * 6
apple_width = np.random.random(100) * 6

# %%
plt.scatter(apple_length, apple_width, color="red")

# %%
apple_length = np.random.normal(6, 0.5, 400)
apple_width = np.random.normal(6, 0.5, 400)

# %%
banana_length = np.random.normal(8, 0.5, 400)
banana_width = np.random.normal(4, 0.5, 400)

# %%
plt.scatter(apple_length, apple_width, color="red")
plt.scatter(banana_length, banana_width, color="yellow")

plt.xlabel("length")
plt.ylabel("width")
plt.title("Apples and bananas dimensions")
plt.show()
